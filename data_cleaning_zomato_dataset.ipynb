# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
data = pd.read_csv('data/zomato.csv')

# %%
data.tail(2)
# Out:
#                                                      url  \
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes           phone                    location  \
# 51715        Yes  4.3 /5    236    080 49652769  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  +91 8071117272  ITPL Main Road, Whitefield
#
#                 rest_type                    dish_liked  \
# 51715                 Bar  Cocktails, Pizza, Buttermilk
# ...

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
data.shape
# Out:
# (51717, 17)

# %% [markdown]
# ## Deleting redundant columns

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
columns_to_keep = ['name', 'online_order', 'book_table', 'rate', 'dish_liked', 'approx_cost(for two people)']
columns_to_drop = ['url', 'address', 'votes', 'phone', 'location', 'rest_type', 'cuisines', 'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)']

# %%
len(columns_to_keep)
# Out:
# 6

# %%
len(columns_to_drop)
# Out:
# 11

# %% [markdown]
# # 1st Filtering Data

# %%
# type - pd.Series 

type(data['name'])
# Out:
# pandas.core.series.Series

# %%
# type -pd.DataFrame

type(data[["name", "url"]])
# Out:
# pandas.core.frame.DataFrame

# %%
modify_data = data[columns_to_keep]

# %%
modify_data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# # 2nd way, dropping the columns

# %%
columns_to_drop
# Out:
# ['url',
#  'address',
#  'votes',
#  'phone',
#  'location',
#  'rest_type',
#  'cuisines',
#  'reviews_list',
#  'menu_item',
#  'listed_in(type)',
#  'listed_in(city)']

# %%
data.drop(columns=columns_to_drop, inplace=True)

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# # Renaming the columns

# %%
data.rename(columns={"name": "name1", "online_order": "onlineorder123"})
# Out:
#                                                    name1 onlineorder123  \
# 0                                                  Jalsa            Yes
# 1                                         Spice Elephant            Yes
# 2                                        San Churro Cafe            Yes
# 3                                  Addhuri Udupi Bhojana             No
# 4                                          Grand Village             No
# ...                                                  ...            ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...             No
# 51713                           Vinod Bar And Restaurant             No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...             No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...             No
# 51716                       The Nest - The Den Bengaluru             No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'dish_liked',
#        'approx_cost(for two people)'],
#       dtype='object')

# %%
data.columns[0].capitalize()
# Out:
# 'Name'

# %%
for i in data.columns:
    print(i.capitalize())
# Out:
# Name
# Online_order
# Book_table
# Rate
# Dish_liked
# Approx_cost(for two people)

# %%
new_colunmn_names = []
for i in data.columns:
    new_colunmn_names.append(i.capitalize())

# %%
new_colunmn_names
# Out:
# ['Name',
#  'Online_order',
#  'Book_table',
#  'Rate',
#  'Dish_liked',
#  'Approx_cost(for two people)']

# %%
data.columns = new_colunmn_names

# %%
data
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Online_order', 'Book_table', 'Rate', 'Dish_liked',
#        'Approx_cost(for two people)'],
#       dtype='object')

# %% [markdown]
# # Dropping duplicates

# %%
data.duplicated().sum()
# Out:
# np.int64(32808)

# %%
data.duplicated().value_counts()
# Out:
# True     32808
# False    18909
# Name: count, dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Remove the NaN values from dataset

# %%
data.isna().sum()
# Out:
# Name                               0
# Online_order                       0
# Book_table                         0
# Rate                            2418
# Dish_liked                     10587
# Approx_cost(for two people)      140
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Name                           0
# Online_order                   0
# Book_table                     0
# Rate                           0
# Dish_liked                     0
# Approx_cost(for two people)    0
# dtype: int64

# %%
data
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51611                                    Chung Wah           No         No
# 51617                              Breakfast House           No         No
# 51620                               Fujian Express          Yes         No
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51677                                      Bhagini           No         No
#
#          Rate                                         Dish_liked  \
# ...

# %%
data.reset_index(inplace=True)

# %% [markdown]
# # Cleaning individual columns

# %%
data
# Out:
#       index                                         Name Online_order  \
# 0         0                                        Jalsa          Yes
# 1         1                               Spice Elephant          Yes
# 2         2                              San Churro Cafe          Yes
# 3         3                        Addhuri Udupi Bhojana           No
# 4         4                                Grand Village           No
# ...     ...                                          ...          ...
# 8245  51611                                    Chung Wah           No
# 8246  51617                              Breakfast House           No
# 8247  51620                               Fujian Express          Yes
# 8248  51628  Nook - Aloft Bengaluru Cessna Business Park           No
# 8249  51677                                      Bhagini           No
#
#      Book_table    Rate                                         Dish_liked  \
# ...

# %%
data.drop(columns="index", inplace=True)

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#         Rate                                         Dish_liked  \
# ...

# %%
data['Rate'] = data['Rate'].str.replace(" ", "")
data['Rate'] = data['Rate'].str.replace("/"," out of ")

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#               Rate                                         Dish_liked  \
# ...

# %% [markdown]
# # Check for some more Transformations

# %%
data['Online_order']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3        No
# 4        No
#        ...
# 8245     No
# 8246     No
# 8247    Yes
# 8248     No
# 8249     No
# Name: Online_order, Length: 8250, dtype: object

# %%
data['Online_order'].apply(lambda x: 1 if x == "Yes" else 0)
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 8245    0
# 8246    0
# 8247    1
# 8248    0
# 8249    0
# Name: Online_order, Length: 8250, dtype: int64

# %%
data['Online_order'] = data['Online_order'].apply(lambda x: 1 if x == "Yes" else 0)

# %%
data
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...

# %% [markdown]
# ## Export Data
# ### Save DataFrmae in .csv and .xlsx

# %%
data.to_csv('data/cleaned_zomato_file.csv')

# %%
pd.read_csv('data/cleaned_zomato_file.csv', engine='pyarrow')
# Out:
#                                                    Name  Online_order  \
# 0        0                                        Jalsa             1
# 1        1                               Spice Elephant             1
# 2        2                              San Churro Cafe             1
# 3        3                        Addhuri Udupi Bhojana             0
# 4        4                                Grand Village             0
# ...    ...                                          ...           ...
# 8245  8245                                    Chung Wah             0
# 8246  8246                              Breakfast House             0
# 8247  8247                               Fujian Express             1
# 8248  8248  Nook - Aloft Bengaluru Cessna Business Park             0
# 8249  8249                                      Bhagini             0
#
#      Book_table          Rate  \
# 0           Yes  4.1 out of 5
# 1            No  4.1 out of 5
# 2            No  3.8 out of 5
# ...

# %%
data.to_csv('data/cleaned_zomato_file_no_index.csv', index= False)

# %%
pd.read_csv('data/cleaned_zomato_file_no_index.csv', engine='pyarrow')
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...

# %%
data.to_excel('data/cleaned_zomato_excel.xlsx')

# %%
pd.read_excel('data/cleaned_zomato_excel.xlsx', engine='calamine')
# Out:
#       Unnamed: 0                                         Name  Online_order  \
# 0              0                                        Jalsa             1
# 1              1                               Spice Elephant             1
# 2              2                              San Churro Cafe             1
# 3              3                        Addhuri Udupi Bhojana             0
# 4              4                                Grand Village             0
# ...          ...                                          ...           ...
# 8245        8245                                    Chung Wah             0
# 8246        8246                              Breakfast House             0
# 8247        8247                               Fujian Express             1
# 8248        8248  Nook - Aloft Bengaluru Cessna Business Park             0
# 8249        8249                                      Bhagini             0
#
#      Book_table          Rate  \
# ...

# %%
data.to_excel('data/cleaned_zomato_excel_no_index.xlsx', index=False)

# %%
pd.read_excel('data/cleaned_zomato_excel_no_index.xlsx', engine='calamine')
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...
